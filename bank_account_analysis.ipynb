# %% [markdown]
# # Project Overview

# %% [markdown]
# ## Dataset description:
# The dataset contains demographic information and what financial services are used by approximately 33,600 individuals across East Africa. The ML model role is to predict which individuals are most likely to have or use a bank account.
#
# The term financial inclusion means:  individuals and businesses have access to useful and affordable financial products and services that meet their needs – transactions, payments, savings, credit and insurance – delivered in a responsible and sustainable way.
#
# Variables definitions:
#
# **country**- Country interviewee is in.
#
# **year**-	Year survey was done in.
#
# **uniqueid**-	Unique identifier for each interviewee
#
# **location_type**-	Type of location: Rural, Urban
#
# **cellphone_access**-	If interviewee has access to a cellphone: Yes, No
#
# **household_size**-	Number of people living in one house
#
# **age_of_respondent**-	The age of the interviewee
#
# **gender_of_respondent**-	Gender of interviewee: Male, Female
#
# **relationship_with_head**-	The interviewee’s relationship with the head of the house:Head of Household, Spouse, Child, Parent, Other relative, Other non-relatives, Dont know
#
# **marital_status**-	The martial status of the interviewee: Married/Living together, Divorced/Seperated, Widowed, Single/Never Married, Don’t know
#
# **education_level**-	Highest level of education: No formal education, Primary education, Secondary education, Vocational/Specialised training, Tertiary education, Other/Dont know/RTA
#
# **job_type**-	Type of job interviewee has: Farming and Fishing, Self employed, Formally employed Government, Formally employed Private, Informally employed, Remittance Dependent, Government Dependent, Other Income, No Income, Dont Know/Refuse to answer

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import RandomizedSearchCV
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
import joblib

# %%
# load dataset in a dataframe
df = pd.read_csv("Financial_inclusion_dataset.csv")
df.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
# check the information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
# check descriptive statistics
df.describe()
# Out:
#                year  household_size  age_of_respondent
# count  23524.000000    23524.000000       23524.000000
# mean    2016.975939        3.797483          38.805220
# std        0.847371        2.227613          16.520569
# min     2016.000000        1.000000          16.000000
# 25%     2016.000000        2.000000          26.000000
# 50%     2017.000000        3.000000          35.000000
# 75%     2018.000000        5.000000          49.000000
# max     2018.000000       21.000000         100.000000

# %%
# check for missing values
df.isnull().sum()
# Out:
# country                   0
# year                      0
# uniqueid                  0
# bank_account              0
# location_type             0
# cellphone_access          0
# household_size            0
# age_of_respondent         0
# gender_of_respondent      0
# relationship_with_head    0
# marital_status            0
# education_level           0
# job_type                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'bank_account', 'location_type',
#        'cellphone_access', 'household_size', 'age_of_respondent',
#        'gender_of_respondent', 'relationship_with_head', 'marital_status',
#        'education_level', 'job_type'],
#       dtype='object')

# %%
# Get more insight through a profile report

#profile = ProfileReport(df, title="Africa financial inclusion analysis")
#profile.to_file("Africa_financial_inclusion_analysis.html")

# %%
#profile

# %%
# drop unnecessary columns
df.drop(columns=['uniqueid', 'marital_status', 'gender_of_respondent'], inplace=True)
df.head()
# Out:
#   country  year bank_account location_type cellphone_access  household_size  \
# 0   Kenya  2018          Yes         Rural              Yes               3
# 1   Kenya  2018           No         Rural               No               5
# 2   Kenya  2018          Yes         Urban              Yes               5
# 3   Kenya  2018           No         Rural              Yes               5
# 4   Kenya  2018           No         Urban               No               8
#
#    age_of_respondent relationship_with_head                  education_level  \
# 0                 24                 Spouse              Secondary education
# 1                 70      Head of Household              No formal education
# 2                 26         Other relative  Vocational/Specialised training
# 3                 34      Head of Household                Primary education
# 4                 26                  Child                Primary education
#
#                     job_type
# ...

# %% [markdown]
# # Feature Engineering

# %%
bins = [0, 18, 25, 35, 45, 55, 65, np.inf]
labels = ['<18', '18-24', '25-34', '35-44', '45-54', '55-64', '65+']
df['age_group'] = pd.cut(df['age_of_respondent'], bins=bins, labels=labels)

# %%
df.drop(columns=[ 'age_of_respondent'], inplace=True)

# %%
# create a new copy of original dataframe
new_df = df.copy()

# %% [markdown]
# # Feature Scaling

# %%
# Scaling features
#features_to_scale = ['household_size', 'age_group', 'year']
#scaler = MinMaxScaler()
#_features[features_to_scale] = scaler.fit_transform(features[features_to_scale])

# %% [markdown]
# # Encode categorical columns

# %%
# Encode our categorical data
categorical_columns = ['country','bank_account', 'location_type', 'cellphone_access', 
                       'relationship_with_head',  'education_level', 'job_type', 'age_group']

le = LabelEncoder()

for col in categorical_columns:
    new_df[col] = le.fit_transform(new_df[col])

new_df.head()
# Out:
#    country  year  bank_account  location_type  cellphone_access  \
# 0        0  2018             1              0                 1
# 1        0  2018             0              0                 0
# 2        0  2018             1              1                 1
# 3        0  2018             0              0                 1
# 4        0  2018             0              1                 0
#
#    household_size  relationship_with_head  education_level  job_type  \
# 0               3                       5                3         9
# 1               5                       1                0         4
# 2               5                       3                5         9
# 3               5                       1                2         3
# 4               8                       0                2         5
#
#    age_group
# 0          0
# 1          5
# 2          1
# 3          1
# 4          1

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  int64
#  1   year                    23524 non-null  int64
#  2   bank_account            23524 non-null  int64
#  3   location_type           23524 non-null  int64
#  4   cellphone_access        23524 non-null  int64
#  5   household_size          23524 non-null  int64
#  6   relationship_with_head  23524 non-null  int64
#  7   education_level         23524 non-null  int64
#  8   job_type                23524 non-null  int64
#  9   age_group               23524 non-null  int64
# dtypes: int64(10)
# memory usage: 1.8 MB

# %%
def print_encoding_mapping(original_column, encoded_column):
    mapping = pd.DataFrame({ 'original': original_column, 'encoded': encoded_column })
    print(mapping.drop_duplicates().reset_index(drop=True))

# Example usage
print_encoding_mapping(df['country'], new_df['country'])
# Out:
#    original  encoded
# 0     Kenya        0
# 1    Rwanda        1
# 2  Tanzania        2
# 3    Uganda        3

# %%
print_encoding_mapping(df['location_type'], new_df['location_type'])
# Out:
#   original  encoded
# 0    Rural        0
# 1    Urban        1

# %%
print_encoding_mapping(df['cellphone_access'], new_df['cellphone_access'])
# Out:
#   original  encoded
# 0      Yes        1
# 1       No        0

# %%
print_encoding_mapping(df['age_group'], new_df['age_group'])
# Out:
#   original  encoded
# 0    18-24        0
# 1      65+        5
# 2    25-34        1
# 3    35-44        2
# 4    45-54        3
# 5    55-64        4
# 6      <18        6

# %%
print_encoding_mapping(df['relationship_with_head'], new_df['relationship_with_head'])
# Out:
#               original  encoded
# 0               Spouse        5
# 1    Head of Household        1
# 2       Other relative        3
# 3                Child        0
# 4               Parent        4
# 5  Other non-relatives        2

# %%
print_encoding_mapping(df['education_level'], new_df['education_level'])
# Out:
#                           original  encoded
# 0              Secondary education        3
# 1              No formal education        0
# 2  Vocational/Specialised training        5
# 3                Primary education        2
# 4               Tertiary education        4
# 5              Other/Dont know/RTA        1

# %%
print_encoding_mapping(df['job_type'], new_df['job_type'])
# Out:
#                        original  encoded
# 0                 Self employed        9
# 1          Government Dependent        4
# 2     Formally employed Private        3
# 3           Informally employed        5
# 4  Formally employed Government        2
# 5           Farming and Fishing        1
# 6          Remittance Dependent        8
# 7                  Other Income        7
# 8    Dont Know/Refuse to answer        0
# 9                     No Income        6

# %% [markdown]
# # Check correlation between variables and bank_account

# %%
plt.figure(figsize=(10,5))
sns.heatmap(new_df.corr(), annot=True)
plt.title('Correlation feature matrix')
plt.show()

# %% [markdown]
# the correlation between the features and bank account aren't strong but that doesn't mean correlation leads to causation there may be various factors.

# %% [markdown]
# # Split dataset into features and target

# %%
# Define features and labels
X = new_df.drop(columns=['bank_account'])  
y = new_df['bank_account']

# %%
# Scale numerical features
features_to_scale = ['household_size', 'year'] 

scaler = MinMaxScaler()

X[features_to_scale] = scaler.fit_transform(X[features_to_scale])

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Apply SMOTE to oversample the minority class
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Apply RandomUnderSampler to undersample the majority class
rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train_resampled, y_train_resampled)

# %% [markdown]
# # Implement Random Forest Algorithm

# %%
# Initialize Random Forest Classifier
clf = RandomForestClassifier(class_weight={0: 1, 1: 2},random_state=42)

# %%
# Define the parameter grid
param_dist = {
    'n_estimators': [50, 100, 200, 300],
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'class_weight': ['balanced']
}

# %%
# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=clf, param_distributions=param_dist, n_iter=10, cv=5, n_jobs=-1, verbose=2, random_state=42, scoring='f1')

# %%
# Fit the model to the training data
random_search.fit(X_train_resampled, y_train_resampled)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestClassifier(class_weight={0: 1, 1: 2},
#                                                     random_state=42),
#                    n_jobs=-1,
#                    param_distributions={'class_weight': ['balanced'],
#                                         'max_depth': [None, 10, 20, 30, 40],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [50, 100, 200, 300]},
#                    random_state=42, scoring='f1', verbose=2)
# [CV] END class_weight=balanced, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.5s
# ...

# %%
# Best parameters found by RandomizedSearchCV
print("Best parameters found: ", random_search.best_params_)
# Out:
# Best parameters found:  {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': None, 'class_weight': 'balanced'}

# %% [markdown]
# # Make predictions

# %%
# Best estimator
best_rf_random = random_search.best_estimator_

# %%
# Make predictions

y_pred = best_rf_random.predict(X_test)

# %% [markdown]
# # Evaluate the model

# %%
# Metrics
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8362142249929159

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', cbar=False, xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrrix for Bank Account Prediction')
#plt.savefig('onfusion Matrrix for Bank Account Prediction.png')
plt.show()

# %%
print(f"Precision = {class_report}")
# Out:
# Precision =               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90      6073
#            1       0.43      0.52      0.47       985
#
#     accuracy                           0.84      7058
#    macro avg       0.67      0.70      0.69      7058
# weighted avg       0.85      0.84      0.84      7058

# %%
# Get the column names
feature_names = X.columns

# Get feature importances from the fitted model
importances = best_rf_random.feature_importances_

# Create a DataFrame to display the feature importances
feature_imp_df = pd.DataFrame({'Feature': feature_names, 'Gini Importance': importances}).sort_values('Gini Importance', ascending=False)

feature_imp_df
# Out:
#                   Feature  Gini Importance
# 4          household_size         0.284462
# 6         education_level         0.181751
# 8               age_group         0.119184
# 7                job_type         0.116489
# 3        cellphone_access         0.099744
# 0                 country         0.062205
# 5  relationship_with_head         0.057927
# 1                    year         0.042682
# 2           location_type         0.035556

# %%
plt.figure(figsize=(10, 6))
plt.barh(feature_imp_df['Feature'], feature_imp_df['Gini Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance from Random Forest')
plt.gca().invert_yaxis()
#plt.savefig('Feature Importance from Random Forest.png')
plt.show()

# %% [markdown]
# # Interpretation of feature importance

# %% [markdown]
# **Top Features by Importance:**
#
# **Education Level (0.237):**  The most important predictor in your model, indicating that higher education levels may correlate strongly with financial inclusion.
#
# **Age of Respondent (0.196):** Age plays a significant role, likely because financial behavior changes with age.
#
# **Cellphone Access (0.129):** Access to a cellphone is also highly important, as mobile banking and financial services often require mobile access.
#
# **Job Type (0.108):** Employment status and type of job influence access to financial services.
#
# **Least Important Features:**
#
# **Gender of Respondent (0.028):** Gender seems to have the least importance in the model, meaning it has a lower influence on the prediction.
#
# **Marital Status (0.031):** Similarly, marital status is less important compared to education and age.

# %% [markdown]
# After the feature importance the gender of the respondent and marital status was dropped as they had the least importance. Now after scaling, and feature engineering household size plays a major role followed by age group with the highest being education level.

# %%
# Save the model  to use in Streamlit 
joblib.dump(best_rf_random, 'random_forest_model.pkl')
# Out:
# ['random_forest_model.pkl']

# %%
#Save the encoder after fitting it on your training data
joblib.dump(le, 'label_encoder.pkl')
# Out:
# ['label_encoder.pkl']

# %%
# Save the fitted scaler 
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %% [markdown]
# # Insights

# %% [markdown]
# classification report shows improvements in recall for class 1 (53%), compared to the previous ones, which means the model is identifying more of the minority class instances (bank account holders) correctly.
#
# Key insights:
#
# Precision for class 1 (0.42): Precision remains lower for class 1, meaning there are still quite a few false positives (incorrectly predicting class 1 that is that an individual has a bank account).
#
# Recall for class 1 (0.53): This has improved, suggesting that more of the true positives are being captured, but it's still low compared to class 0.
#
# Accuracy (0.83): The overall accuracy is quite high, but as the dataset is imbalanced, this is not the most important metric.
#
# Macro average (0.67 precision, 0.71 recall): The macro average shows the overall balance between classes.

# %%
X_train.head()
# Out:
#        country  year  location_type  cellphone_access  household_size  \
# 19929        2   0.5              1                 1            0.05
# 13449        1   0.0              0                 1            0.15
# 5449         0   1.0              1                 1            0.15
# 6956         1   0.0              0                 1            0.20
# 2737         0   1.0              0                 0            0.20
#
#        relationship_with_head  education_level  job_type  age_group
# 19929                       5                2         8          0
# 13449                       1                3         1          3
# 5449                        1                3         9          2
# 6956                        1                0         1          4
# 2737                        5                2         1          0
